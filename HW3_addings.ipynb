# %% [markdown]
# # HOMEWORK 3 to Lesson 6
# ## Задание к Уроку 6 " Обучение с учителем в Scikit-learn"

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pylab import rcParams as rc

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
#  ### *Дополнительные задания:
#
#  ####  1). Загрузите датасет Wine из встроенных датасетов sklearn.datasets с помощью функции load_wine в переменную data.

# %%
from sklearn.datasets import load_wine
data = load_wine()

# %% [markdown]
# #### 2). Полученный датасет не является датафреймом. Это структура данных, имеющая ключи аналогично словарю. Просмотрите тип данных этой структуры данных и создайте список data_keys,содержащий ее ключи.

# %%
data_keys = data.keys()
data_keys
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# #### 3). Просмотрите данные, описание и названия признаков в датасете.  Описание нужно вывести в виде привычного, аккуратно оформленного текста, без обозначений переноса строки, но с самими переносами и т.д.

# %%
print(' data: \n{}\n\n  DESCR: \n {}\n\n features: \n {}'.format(data['data'], data['DESCR'],data_keys))
# Out:
#  data:
# [[1.423e+01 1.710e+00 2.430e+00 ... 1.040e+00 3.920e+00 1.065e+03]
#  [1.320e+01 1.780e+00 2.140e+00 ... 1.050e+00 3.400e+00 1.050e+03]
#  [1.316e+01 2.360e+00 2.670e+00 ... 1.030e+00 3.170e+00 1.185e+03]
#  ...
#  [1.327e+01 4.280e+00 2.260e+00 ... 5.900e-01 1.560e+00 8.350e+02]
#  [1.317e+01 2.590e+00 2.370e+00 ... 6.000e-01 1.620e+00 8.400e+02]
#  [1.413e+01 4.100e+00 2.740e+00 ... 6.100e-01 1.600e+00 5.600e+02]]
#
#   DESCR:
#  .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
# ...

# %% [markdown]
# #### 4). Сколько классов содержит целевая переменная датасета? Выведите названия классов.

# %%
print('Кол-во классов в датасете: {}\nИмена классов: {}'.format(len(data.target_names), data.target_names))
# Out:
# Кол-во классов в датасете: 3
# Имена классов: ['class_0' 'class_1' 'class_2']

# %% [markdown]
# #### 5). На основе данных датасета (они содержатся в двумерном массиве Numpy) и названий признаков создайте датафрейм под названием X.

# %%
X = pd.DataFrame(data.data, columns = data.feature_names )
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# #### 6). Выясните размер датафрейма X и установите, имеются ли в нем пропущенные значения.

# %%
print('Размер датафрейма X :{}\nКол-во данных: {}'.format(X.shape, X.size))
# Out:
# Размер датафрейма X :(178, 13)
# Кол-во данных: 2314

# %%
X.info(null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# **ОТВЕТ:** Пропущенных значений нет,т.к исходя из размерности датафрейма 178 строк, все 178 стро по каждому признаку NON-NULL

# %% [markdown]
# #### 7). Добавьте в датафрейм поле с классами вин в виде чисел, имеющих тип данных numpy.int64. Название поля - 'target'.

# %%
X['target'] = (data.target).astype('int64')
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# #### 8). Постройте матрицу корреляций для всех полей X. Дайте полученному датафрейму название X_corr.

# %%
X_corr = X.corr()
X_corr
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
# target                       -0.328222    0.437776 -0.049643
#
# ...

# %%
import seaborn as sns

plt.figure(figsize = (10,8))

sns.set(font_scale=1)

X_corr_new = np.round(X_corr, 2) # Округляем значение корреляции до 2 знаков после запятой

X_corr_new[np.abs(X_corr)<0.2] = 0 # Упрощаем отображение данных, по корреляции,оставив наиболеее полезные значения

sns.heatmap(X_corr, annot=True, linewidths=.5, cmap='coolwarm')

plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# #### 9). Создайте список high_corr из признаков, корреляция которых с полем target по абсолютному значению превышает 0.5 (причем, само поле target не должно входить в этот список).

# %%
a = X_corr['target'].drop('target') # Убираем столбец target из признаков

a = a.loc[np.absolute(a)>0.5] # Поиск полей,где выполняется условия корреляии больше 0.5

# %%
X_corr = X.corr()
X_corr['target']
# Out:
# alcohol                        -0.328222
# malic_acid                      0.437776
# ash                            -0.049643
# alcalinity_of_ash               0.517859
# magnesium                      -0.209179
# total_phenols                  -0.719163
# flavanoids                     -0.847498
# nonflavanoid_phenols            0.489109
# proanthocyanins                -0.499130
# color_intensity                 0.265668
# hue                            -0.617369
# od280/od315_of_diluted_wines   -0.788230
# proline                        -0.633717
# target                          1.000000
# Name: target, dtype: float64

# %%
high_corr = [a.index[i] for i in range(len(a.index))]

# %%
type(high_corr)
# Out:
# list

# %%
print(high_corr)
# Out:
# ['alcalinity_of_ash', 'total_phenols', 'flavanoids', 'hue', 'od280/od315_of_diluted_wines', 'proline']

# %% [markdown]
# #### 10). Удалите из датафрейма X поле с целевой переменной.
# #### Для всех признаков, названия которых содержатся в списке high_corr, вычислите квадрат их значений и добавьте в датафрейм X соответствующие поля с суффиксом '_2', добавленного к первоначальному названию признака.
#
# #### Итоговый датафрейм должен содержать все поля, которые, были в нем изначально, а также поля с признаками из списка high_corr, возведенными в квадрат. Выведите описание полей датафрейма X с помощью метода describe.

# %%
X_corr['target'].drop('target')
# Out:
# alcohol                        -0.328222
# malic_acid                      0.437776
# ash                            -0.049643
# alcalinity_of_ash               0.517859
# magnesium                      -0.209179
# total_phenols                  -0.719163
# flavanoids                     -0.847498
# nonflavanoid_phenols            0.489109
# proanthocyanins                -0.499130
# color_intensity                 0.265668
# hue                            -0.617369
# od280/od315_of_diluted_wines   -0.788230
# proline                        -0.633717
# Name: target, dtype: float64

# %%
sq = np.square(X[[high_corr[i] for i in range(len(high_corr))]])
sq
# Out:
#      alcalinity_of_ash  total_phenols  flavanoids     hue  \
# 0               243.36         7.8400      9.3636  1.0816
# 1               125.44         7.0225      7.6176  1.1025
# 2               345.96         7.8400     10.4976  1.0609
# 3               282.24        14.8225     12.1801  0.7396
# 4               441.00         7.8400      7.2361  1.0816
# ..                 ...            ...         ...     ...
# 173             420.25         2.8224      0.3721  0.4096
# 174             529.00         3.2400      0.5625  0.4900
# 175             400.00         2.5281      0.4761  0.3481
# 176             400.00         2.7225      0.4624  0.3600
# 177             600.25         4.2025      0.5776  0.3721
#
#      od280/od315_of_diluted_wines    proline
# 0                         15.3664  1134225.0
# 1                         11.5600  1102500.0
# 2                         10.0489  1404225.0
# 3                         11.9025  2190400.0
# ...

# %%
for i in range(len(sq.columns)):
    l = lambda a1,a2:'_'.join([a1, str(a2)])
    a1 = sq.columns[i]
    a2 = 2
    X[l(a1,a2)] = sq[a1]

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
X.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...
